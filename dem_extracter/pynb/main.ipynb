# %%
# main script

'''
this is the project for correcting hight from lichi mission

'''


import argparse
import subprocess
import pandas as pd
import os

# %% [markdown]
# 使用 subprocess 調用的寫法

# %%
def main():

    # 命列列部分
    ## 整個程式主要的I/O
    '''
   
    parser = argparse.ArgumentParser(description="Main script to revice flight mission.")
    parser.add_argument('dem_file', type=str, help="Path to the DEM file")
    parser.add_argument('csv_file', type=str, help="Path to the input CSV file")
    parser.add_argument('output_file', type=str, help="Path to save the modified CSV file")

    args = parser.parse_args()
    '''

    # 資料前處理
    ## 將csv的座標提取成x_coord, y_coord
    '''
    pts = pd.read_csv(args.csv_file)
    outpath = args.output_file

    '''

    
    dem = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\Dali_2m_H.tif"
    csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\test_data.csv"
    

    # 調用 extract_dem.py
    ## 通過 subprocess 調用 extract_dem.py 並傳遞參數
    #pts['elev'] = subprocess.run(['python', 'extract_dem.py', args.dem_file, x_coords , y_coords])
    subprocess.run(['python', 'extract_dem.py', dem,csvpath])
    # 調用其他程式、語言
    


if __name__ == "__main__":
    main()

# %% [markdown]
# 若僅需要單獨調用 extract_dem 方法的寫法

# %%
dem = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\Dali_2m_H.tif"
csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\test_data.csv"
output_path = 'C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\answer_data.csv'

from extract_dem import extractElevation, convertToTerrain, csv_to_list

# read csv
x_coords,y_coords,elev,orignal_dem = csv_to_list(csvpath)


## return x_coords,y_coords,elev,orignal_dem

extracted_dem = extractElevation(dem,x_coords,y_coords)

# return a list of extracted_dem

new_elev = convertToTerrain(elev,orignal_dem,extracted_dem)
#return a list of revised elev

data = list(zip(x_coords, y_coords, elev, orignal_dem))
answer_df = pd.DataFrame(data, columns=['x_coords', 'y_coords', 'elev', 'orignal_dem'])


answer_df['elev'] = new_elev
answer_df['extracted_dem'] = extracted_dem 
output_path = 'C:\\Users\\USER\\Documents\\GitHub\\collection\\dem_extracter\\test_data\\answer_data.csv'
answer_df .to_csv(output_path, index=False)
print(f"Output saved to {output_path}")

# %% [markdown]
# 透過程式中匯入args參數的寫法(最終版)

# %%
    dem = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\Dali_2m_H.tif"
    csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\test_data.csv"
    costom_path = 'C:\\Users\\USER\\Documents\\GitHub\\collection\\dem_extracter\\test_data\\costom_data.csv'
    default_path = set_output_path()

# %%
def set_output_path(dir_path,filename=None): # 必田參數在前，選填參數在後
    if filename:
        # Check if the filename ends with .csv
        if not filename.endswith('.csv'):
            filename = filename + '.csv'
            #print("auto add .csv")

        output_dir = os.path.dirname(dir_path) # 需要解決路徑問題
        costom_path = os.path.join(output_dir, filename) # 預設檔名與csvfile相同
        # 自訂路徑功能目前尚未添加
        output_path = costom_path
        #print("create costom filename")
    else:
        # Default to the same directory as csvpath
        output_path = os.path.dirname(dir_path)
        # Ensure the output path ends with a directory separator
        output_path = os.path.join(output_path, 'answer_data.csv')
        #print("create default filename")
    
    return output_path

csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\test_data.csv"
filename = input("please insert filename for the output file (example: 'answer_data.csv'):")
output_path = set_output_path(csvpath,filename)
print(output_path)
# Out:
# auto add .csv
# create costom filename
# C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\ .csv

# %%
資料測試

# %%
import main 
from extract_dem import main as extract_dem_main
a = [dem,csvpath,costom_path]
extract_dem_main(a)

csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\test_data.csv"
filename = input("please insert filename for the output file (example: 'answer_data.csv'):")
output_path = main.set_output_path(csvpath,filename)
print(output_path)

# %%
from extract_dem import main as extract_dem_main
filename = input("please insert filename for the output file (example: 'answer_data.csv'):")
output_path = set_output_path(csvpath,filename)

a = [dem,csvpath,output_path]
extract_dem_main(a)

dem = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\Dali_2m_H.tif"
csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\lichi_example.csv"

aa = [dem,csvpath]
main(aa)

# %%
csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\lichi_example.csv"
pts = pd.read_csv(csvpath)
pts
# Out:
#      latitude   longitude  altitude(m)  heading(deg)  curvesize(m)  \
# 0   24.965710  121.916089           40             0      5.000000
# 1   24.965824  121.916088           40             0      1.000000
# 2   24.966280  121.916084           40             0      1.000000
# 3   24.966394  121.916083           40             0      9.821826
# 4   24.966510  121.916277           40           180      9.821826
# ..        ...         ...          ...           ...           ...
# 83  24.967563  121.919965           40             0      9.821826
# 84  24.967450  121.920160           40           180      9.821826
# 85  24.967336  121.920161           40           180      1.000000
# 86  24.966994  121.920164           40           180      1.000000
# 87  24.966880  121.920165           40           180      1.000000
#
#     rotationdir  gimbalmode  gimbalpitchangle  actiontype1  actionparam1  ...  \
# 0             0           2               -80           -1             0  ...
# 1             0           2               -80           -1             0  ...
# 2             0           2               -80           -1             0  ...
# 3             0           2               -80           -1             0  ...
# 4             0           2               -80           -1             0  ...
# ..          ...         ...               ...          ...           ...  ...
# 83            0           2               -80           -1             0  ...
# 84            0           2               -80           -1             0  ...
# 85            0           2               -80           -1             0  ...
# 86            0           2               -80           -1             0  ...
# 87            0           2               -80           -1             0  ...
#
#     actiontype15  actionparam15  altitudemode  speed(m/s)  poi_latitude  \
# 0             -1              0             0   10.000000             0
# 1             -1              0             0   10.000000             0
# 2             -1              0             0   10.000000             0
# 3             -1              0             0    5.000000             0
# 4             -1              0             0   10.000000             0
# ..           ...            ...           ...         ...           ...
# 83            -1              0             0    5.000000             0
# 84            -1              0             0   10.000000             0
# 85            -1              0             0   10.000000             0
# 86            -1              0             0   10.000000             0
# 87            -1              0             0    2.777778             0
#
#     poi_longitude  poi_altitude(m)  poi_altitudemode  photo_timeinterval  \
# 0               0                0                 0                   0
# 1               0                0                 0                   2
# 2               0                0                 0                   0
# 3               0                0                 0                   0
# 4               0                0                 0                   0
# ..            ...              ...               ...                 ...
# 83              0                0                 0                   0
# 84              0                0                 0                   0
# 85              0                0                 0                   2
# 86              0                0                 0                   0
# 87              0                0                 0                  -1
#
#     photo_distinterval
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ..                  ...
# 83                    0
# 84                    0
# 85                    0
# 86                    0
# 87                   -1
#
# [88 rows x 46 columns]

# %% [markdown]
# 尚未更新

# %%
import trans
csvpath = r"C:\Users\USER\Documents\GitHub\collection\dem_extracter\test_data\lichi_example.csv"
geo_df = trans.trans_input(csvpath)
x_coord, y_coord =  trans.WGS84toEPSG4326(geo_df)
print(x_coord)
print(y_coord)
# Out:
# Input waypoint successfully
# Transform successfully
